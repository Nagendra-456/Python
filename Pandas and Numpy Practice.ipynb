# %%
import pandas as pd
flights = pd.read_csv("flights.csv")
# Out:
# C:\Users\NAGENDRA KUMAR MEHER\anaconda3\envs\Package\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
flights.dtypes
# Out:
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# ...

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
flights.axes
# Out:
# [RangeIndex(start=0, stop=5819079, step=1),
#  Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#         'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#         'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#         'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#         'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#         'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#         'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#         'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#        dtype='object')]

# %%
flights.ndim
# Out:
# 2

# %%
flights.size
# Out:
# 180391449

# %%
flights.values
# Out:
# array([[2015, 1, 1, ..., nan, nan, nan],
#        [2015, 1, 1, ..., nan, nan, nan],
#        [2015, 1, 1, ..., nan, nan, nan],
#        ...,
#        [2015, 12, 31, ..., nan, nan, nan],
#        [2015, 12, 31, ..., nan, nan, nan],
#        [2015, 12, 31, ..., nan, nan, nan]], dtype=object)

# %%
flights.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %%
flights.sample(12)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 3420424  2015      8    1            6      OO           5608      N973SW
# 1015556  2015      3    8            7      DL            707      N992DL
# 5435164  2015     12    7            1      DL            668      N935DL
# 5380555  2015     12    3            4      WN           1401      N8630B
# 4837361  2015     10   29            4      DL           1824      N845DN
# 1438519  2015      4    3            5      US            413      N192UW
# 2515941  2015      6    8            1      DL           1669      N591NW
# 934199   2015      3    3            2      US           1958      N709UW
# 3326796  2015      7   27            1      EV           2640      N677AE
# 4042353  2015      9    8            2      UA            342      N17122
# 4625993  2015     10   16            5      WN           1196      N271LV
# 4843299  2015     10   29            4      AA           2498      N001AA
#
# ...

# %%
flights.std()
# Out:
# YEAR                      0.000000
# MONTH                     3.405137
# DAY                       8.783425
# DAY_OF_WEEK               1.988845
# FLIGHT_NUMBER          1757.063999
# SCHEDULED_DEPARTURE     483.751821
# DEPARTURE_TIME          496.423260
# DEPARTURE_DELAY          37.080942
# TAXI_OUT                  8.895574
# WHEELS_OFF              498.009356
# SCHEDULED_TIME           75.210582
# ELAPSED_TIME             74.211072
# AIR_TIME                 72.230822
# DISTANCE                607.784287
# WHEELS_ON               522.187945
# TAXI_IN                   5.638548
# SCHEDULED_ARRIVAL       507.164696
# ARRIVAL_TIME            526.319737
# ARRIVAL_DELAY            39.271297
# DIVERTED                  0.051020
# CANCELLED                 0.123320
# AIR_SYSTEM_DELAY         28.003679
# SECURITY_DELAY            2.143460
# AIRLINE_DELAY            48.161642
# LATE_AIRCRAFT_DELAY      43.197018
# WEATHER_DELAY            20.433336
# dtype: float64

# %%
flights.head(6)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
# 5  2015      1    1            4      DL            806      N3730B
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
# ...

# %%
flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
flights.tail()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
flights.tail(6)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819073  2015     12   31            4      B6             66      N655JB
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5819073            ABQ                 JFK                 2359  ...
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# ...

# %%
flights[flights.isnull().any(axis=1)]
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
flights.loc[6]
# Out:
# YEAR                     2015
# MONTH                       1
# DAY                         1
# DAY_OF_WEEK                 4
# AIRLINE                    NK
# FLIGHT_NUMBER             612
# TAIL_NUMBER            N635NK
# ORIGIN_AIRPORT            LAS
# DESTINATION_AIRPORT       MSP
# SCHEDULED_DEPARTURE        25
# DEPARTURE_TIME           19.0
# DEPARTURE_DELAY          -6.0
# TAXI_OUT                 11.0
# WHEELS_OFF               30.0
# SCHEDULED_TIME          181.0
# ELAPSED_TIME            170.0
# AIR_TIME                154.0
# DISTANCE                 1299
# WHEELS_ON               504.0
# TAXI_IN                   5.0
# SCHEDULED_ARRIVAL         526
# ARRIVAL_TIME            509.0
# ARRIVAL_DELAY           -17.0
# DIVERTED                    0
# CANCELLED                   0
# CANCELLATION_REASON       NaN
# AIR_SYSTEM_DELAY          NaN
# SECURITY_DELAY            NaN
# AIRLINE_DELAY             NaN
# LATE_AIRCRAFT_DELAY       NaN
# WEATHER_DELAY             NaN
# ...

# %%
flights.loc[:6]
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
# 5  2015      1    1            4      DL            806      N3730B
# 6  2015      1    1            4      NK            612      N635NK
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# ...

# %%
flights.loc[:-1]
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, DAY, DAY_OF_WEEK, AIRLINE, FLIGHT_NUMBER, TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY, TAXI_OUT, WHEELS_OFF, SCHEDULED_TIME, ELAPSED_TIME, AIR_TIME, DISTANCE, WHEELS_ON, TAXI_IN, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY, DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY]
# Index: []
#
# [0 rows x 31 columns]

# %%
flights.loc[4:9:2]
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4  2015      1    1            4      AS            135      N527AS
# 6  2015      1    1            4      NK            612      N635NK
# 8  2015      1    1            4      AA           1112      N3LAAA
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 4            SEA                 ANC                   25  ...         259.0
# 6            LAS                 MSP                   25  ...         509.0
# 8            SFO                 DFW                   30  ...         532.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 4          -21.0         0          0                  NaN               NaN
# 6          -17.0         0          0                  NaN               NaN
# 8          -13.0         0          0                  NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# ...

# %%
flights.iloc[6]
# Out:
# YEAR                     2015
# MONTH                       1
# DAY                         1
# DAY_OF_WEEK                 4
# AIRLINE                    NK
# FLIGHT_NUMBER             612
# TAIL_NUMBER            N635NK
# ORIGIN_AIRPORT            LAS
# DESTINATION_AIRPORT       MSP
# SCHEDULED_DEPARTURE        25
# DEPARTURE_TIME           19.0
# DEPARTURE_DELAY          -6.0
# TAXI_OUT                 11.0
# WHEELS_OFF               30.0
# SCHEDULED_TIME          181.0
# ELAPSED_TIME            170.0
# AIR_TIME                154.0
# DISTANCE                 1299
# WHEELS_ON               504.0
# TAXI_IN                   5.0
# SCHEDULED_ARRIVAL         526
# ARRIVAL_TIME            509.0
# ARRIVAL_DELAY           -17.0
# DIVERTED                    0
# CANCELLED                   0
# CANCELLATION_REASON       NaN
# AIR_SYSTEM_DELAY          NaN
# SECURITY_DELAY            NaN
# AIRLINE_DELAY             NaN
# LATE_AIRCRAFT_DELAY       NaN
# WEATHER_DELAY             NaN
# ...

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
flights[['YEAR','MONTH']].agg(['min','mean','max'])
# Out:
#         YEAR      MONTH
# min   2015.0   1.000000
# mean  2015.0   6.524085
# max   2015.0  12.000000

# %%
flights[['YEAR','MONTH','DAY','DAY_OF_WEEK','FLIGHT_NUMBER']].agg(['min','mean','max'])
# Out:
#         YEAR      MONTH        DAY  DAY_OF_WEEK  FLIGHT_NUMBER
# min   2015.0   1.000000   1.000000     1.000000       1.000000
# mean  2015.0   6.524085  15.704594     3.926941    2173.092742
# max   2015.0  12.000000  31.000000     7.000000    9855.000000

# %%
flights[['DEPARTURE_DELAY','ARRIVAL_DELAY']].agg(['min','mean','max'])
# Out:
#       DEPARTURE_DELAY  ARRIVAL_DELAY
# min        -82.000000     -87.000000
# mean         9.370158       4.407057
# max       1988.000000    1971.000000

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
flights.dropna(axis=1, how='all',inplace = True)

# %%
new_flights = flights.dropna(axis=1, how='all',inplace = True)

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
new_flights = flights.isnull()
new_flights
# Out:
#           YEAR  MONTH    DAY  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER  \
# 0        False  False  False        False    False          False
# 1        False  False  False        False    False          False
# 2        False  False  False        False    False          False
# 3        False  False  False        False    False          False
# 4        False  False  False        False    False          False
# ...        ...    ...    ...          ...      ...            ...
# 5819074  False  False  False        False    False          False
# 5819075  False  False  False        False    False          False
# 5819076  False  False  False        False    False          False
# 5819077  False  False  False        False    False          False
# 5819078  False  False  False        False    False          False
#
#          TAIL_NUMBER  ORIGIN_AIRPORT  DESTINATION_AIRPORT  \
# 0              False           False                False
# ...

# %%
new_flights.isnull()
# Out:
#           YEAR  MONTH    DAY  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER  \
# 0        False  False  False        False    False          False
# 1        False  False  False        False    False          False
# 2        False  False  False        False    False          False
# 3        False  False  False        False    False          False
# 4        False  False  False        False    False          False
# ...        ...    ...    ...          ...      ...            ...
# 5819074  False  False  False        False    False          False
# 5819075  False  False  False        False    False          False
# 5819076  False  False  False        False    False          False
# 5819077  False  False  False        False    False          False
# 5819078  False  False  False        False    False          False
#
#          TAIL_NUMBER  ORIGIN_AIRPORT  DESTINATION_AIRPORT  \
# 0              False           False                False
# ...

# %%
flights.isnull()
# Out:
#           YEAR  MONTH    DAY  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER  \
# 0        False  False  False        False    False          False
# 1        False  False  False        False    False          False
# 2        False  False  False        False    False          False
# 3        False  False  False        False    False          False
# 4        False  False  False        False    False          False
# ...        ...    ...    ...          ...      ...            ...
# 5819074  False  False  False        False    False          False
# 5819075  False  False  False        False    False          False
# 5819076  False  False  False        False    False          False
# 5819077  False  False  False        False    False          False
# 5819078  False  False  False        False    False          False
#
#          TAIL_NUMBER  ORIGIN_AIRPORT  DESTINATION_AIRPORT  \
# 0              False           False                False
# ...

# %%
animals = ['Tiger', 'Bear', 'Moose']
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
numbers = [69,44,55]
pd.Series(numbers)
# Out:
# 0    69
# 1    44
# 2    55
# dtype: int64

# %%
mixup = ['banger','awesome',89.0,456]
pd.Series(mixup)
# Out:
# 0     banger
# 1    awesome
# 2       89.0
# 3        456
# dtype: object

# %%
numbers = [1, 2, 3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals = ['Tiger', 'Bear', None]
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers = [1, 2, None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index[3]
# Out:
# 'Taekwondo'

# %%
type(s.index)
# Out:
# pandas.core.indexes.base.Index

# %%
s = pd.Series(['Tiger', 'Bear', 'Moose'], index=['India', 'America', 'Canada'])
s
# Out:
# India      Tiger
# America     Bear
# Canada     Moose
# dtype: object

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports, index=['Golf', 'Sumo', 'Hockey'])
s
# Out:
# Golf      Scotland
# Sumo         Japan
# Hockey         NaN
# dtype: object

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s[3]
# Out:
# 'South Korea'

# %%
s['Golf']
# Out:
# 'Scotland'

# %%
sports = {99: 'Bhutan',
          100: 'Scotland',
          101: 'Japan',
          102: 'South Korea'}
s = pd.Series(sports)

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
total = 0
for item in s:
    total+=item
print(total)
# Out:
# 324.0

# %%
import numpy as np

total = np.sum(s)
print(total)
# Out:
# 324.0

# %%
#this creates a big series of random numbers
s = pd.Series(np.random.randint(0,1000,10000))
s.head()
# Out:
# 0    573
# 1    397
# 2    175
# 3    649
# 4    998
# dtype: int32

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary+=item
# Out:
# 2.45 ms ± 107 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# 118 µs ± 18.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s+=2 #adds two to each item in s using broadcasting
s.head()
# Out:
# 0     575
# 1     399
# 2     177
# 3     651
# 4    1000
# dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label]= value+2
# Out:
# 868 ms ± 7.71 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s+=2
# Out:
# 553 µs ± 65.1 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
s = pd.Series([1, 2, 3])
s.loc['Animal'] = 'Bears'
s
# Out:
# 0             1
# 1             2
# 2             3
# Animal    Bears
# dtype: object

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
cricket_loving_countries
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries.loc['Cricket']
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df.loc['Store 2']
# Out:
# Name                  Vinod
# Item Purchased    Bird Seed
# Cost                    5.0
# Name: Store 2, dtype: object

# %%
df.iloc[2]
# Out:
# Name                  Vinod
# Item Purchased    Bird Seed
# Cost                    5.0
# Name: Store 2, dtype: object

# %%
type(df.loc['Store 2'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (3, 3)

# %%
df.ndim
# Out:
# 2

# %%
df.loc['Store 1']
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5

# %%
df.loc['Store 1', 'Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.T
# Out:
#                  Store 1       Store 1    Store 2
# Name               Chris         Kevyn      Vinod
# Item Purchased  Dog Food  Kitty Litter  Bird Seed
# Cost                22.5           2.5        5.0

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: object

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df.loc['Store 1']['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc[:,['Name', 'Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5
# Store 2  Vinod   5.0

# %%
df.drop('Store 1')
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df = df.copy()
copy_df = copy_df.drop('Store 1')
copy_df
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df.drop?

# %%
del copy_df['Name']
copy_df
# Out:
#         Item Purchased  Cost
# Store 2      Bird Seed   5.0

# %%
df['Location'] = None
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  22.5     None
# Store 1  Kevyn   Kitty Litter   2.5     None
# Store 2  Vinod      Bird Seed   5.0     None

# %%
costs = df['Cost']
costs
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
costs+=2
costs
# Out:
# Store 1    24.5
# Store 1     4.5
# Store 2     7.0
# Name: Cost, dtype: float64

# %%
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  24.5     None
# Store 1  Kevyn   Kitty Litter   4.5     None
# Store 2  Vinod      Bird Seed   7.0     None

# %%
df = pd.read_csv('olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv('olympics.csv', index_col = 0, skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#' + col[1:]}, inplace=True) 

df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df['Gold'] > 0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
#                                                 ...
# Independent Olympic Participants (IOP) [IOP]    False
# Zambia (ZAM) [ZAM]                              False
# Zimbabwe (ZIM) [ZIM]                             True
# Mixed team (ZZX) [ZZX]                           True
# Totals                                           True
# Name: Gold, Length: 147, dtype: bool

# %%
only_gold = df.where(df['Gold'] > 0)
only_gold.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
df['Gold'].count()
# Out:
# 147

# %%
only_gold = only_gold.dropna()
only_gold.head()
# Out:
#                            # Summer   Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                  12.0    5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)                23.0   18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                   5.0    1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]         2.0    3.0     4.0     5.0   12.0       0.0
# Australia (AUS) [AUS] [Z]      25.0  139.0   152.0   177.0  468.0      18.0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                 0.0       0.0       0.0      0.0     15.0
# Argentina (ARG)               0.0       0.0       0.0      0.0     41.0
# Armenia (ARM)                 0.0       0.0       0.0      0.0     11.0
# Australasia (ANZ) [ANZ]       0.0       0.0       0.0      0.0      2.0
# Australia (AUS) [AUS] [Z]     5.0       3.0       4.0     12.0     43.0
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
only_gold = df[df['Gold'] > 0]
only_gold.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
len(df[(df['Gold'] > 0) | (df['Gold.1'] > 0)])
# Out:
# 101

# %%
df[(df['Gold.1'] > 0) & (df['Gold'] == 0)]
# Out:
#                      # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Liechtenstein (LIE)        16     0       0       0      0        18       2
#
#                      Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9       34       2         2
#
#                      Bronze.2  Combined total
# Liechtenstein (LIE)         5               9

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df['country'] = df.index
df = df.set_index('Gold')
df.head()
# Out:
#       # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0           13       0       2      2         0       0         0         0
# 5           12       2       8     15         3       0         0         0
# 18          23      24      28     70        18       0         0         0
# 1            5       2       9     12         6       0         0         0
# 3            2       4       5     12         0       0         0         0
#
#       Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 0           0       13       0         0         2               2
# 5           0       15       5         2         8              15
# 18          0       41      18        24        28              70
# 1           0       11       1         2         9              12
# 3           0        2       3         4         5              12
#
#                       country
# Gold
# 0           Afghanistan (AFG)
# ...

# %%
df = df.reset_index()
df.head()
# Out:
#    Gold  # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  \
# 0     0        13       0       2      2         0       0         0
# 1     5        12       2       8     15         3       0         0
# 2    18        23      24      28     70        18       0         0
# 3     1         5       2       9     12         6       0         0
# 4     3         2       4       5     12         0       0         0
#
#    Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# 0         0        0       13       0         0         2               2
# 1         0        0       15       5         2         8              15
# 2         0        0       41      18        24        28              70
# 3         0        0       11       1         2         9              12
# 4         0        0        2       3         4         5              12
#
#                    country
# 0        Afghanistan (AFG)
# 1            Algeria (ALG)
# ...

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df=df[df['SUMLEV'] == 50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']
df = df[columns_to_keep]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
# 5         618         603            57373            57711            57776
#
# ...

# %%
df = df.set_index(['STNAME', 'CTYNAME'])
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#         Blount County          618         603            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# ...

# %%
df.loc['Michigan', 'Washtenaw County']
# Out:
# BIRTHS2010            977
# BIRTHS2011           3826
# BIRTHS2012           3780
# BIRTHS2013           3662
# BIRTHS2014           3683
# BIRTHS2015           3709
# POPESTIMATE2010    345563
# POPESTIMATE2011    349048
# POPESTIMATE2012    351213
# POPESTIMATE2013    354289
# POPESTIMATE2014    357029
# POPESTIMATE2015    358880
# Name: (Michigan, Washtenaw County), dtype: int64

# %%
df.loc[ [('Michigan', 'Washtenaw County'),
         ('Michigan', 'Wayne County')] ]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#          Wayne County           23607       23586          1815199
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#          Wayne County              1801273          1792514          1775713
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880
#          Wayne County              1766008          1759335

# %%
df = pd.read_csv('log.csv')
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df.fillna?

# %%
df = df.set_index('time')
df = df.sort_index()
df
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN
# 1469974514  cheryl     intro.html                  8    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974554     sue  advanced.html                 26    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN
# 1469974604  cheryl     intro.html                 11    NaN     NaN
# 1469974624     sue  advanced.html                 27    NaN     NaN
# 1469974634  cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df = df.reset_index()
df = df.set_index(['time', 'user'])
df
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df = df.fillna(method='ffill')
df.head()
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %%
import pandas as pd
grades = pd.read_csv("grades.csv")

# %%
grades.shape
# Out:
# (2315, 13)

# %%
grades.describe()
# Out:
#        assignment1_grade  assignment2_grade  assignment3_grade  \
# count        2315.000000        2315.000000        2315.000000
# mean           74.535732          66.849007          60.623197
# std            16.353252          15.959210          15.492469
# min            14.423297          12.980967          12.307682
# 25%            63.670100          56.127794          49.866390
# 50%            77.208365          68.142124          61.307206
# 75%            87.502146          78.310880          71.292632
# max           100.695583          99.936206          99.655813
#
#        assignment4_grade  assignment5_grade  assignment6_grade
# count        2315.000000        2315.000000        2315.000000
# mean           54.112112          48.618522          43.841452
# std            14.687431          13.927054          13.259413
# min             9.126146           8.213531           7.392178
# 25%            43.852636          38.859619          34.828619
# ...

# %%
grades.isnull()
# Out:
#       student_id  assignment1_grade  assignment1_submission  \
# 0          False              False                   False
# 1          False              False                   False
# 2          False              False                   False
# 3          False              False                   False
# 4          False              False                   False
# ...          ...                ...                     ...
# 2310       False              False                   False
# 2311       False              False                   False
# 2312       False              False                   False
# 2313       False              False                   False
# 2314       False              False                   False
#
#       assignment2_grade  assignment2_submission  assignment3_grade  \
# 0                 False                   False              False
# 1                 False                   False              False
# ...

# %%
grades[grades.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [student_id, assignment1_grade, assignment1_submission, assignment2_grade, assignment2_submission, assignment3_grade, assignment3_submission, assignment4_grade, assignment4_submission, assignment5_grade, assignment5_submission, assignment6_grade, assignment6_submission]
# Index: []

# %%
grades.ndim
# Out:
# 2

# %%
grades.size
# Out:
# 30095

# %%
grades.mean()
# Out:
# assignment1_grade    74.535732
# assignment2_grade    66.849007
# assignment3_grade    60.623197
# assignment4_grade    54.112112
# assignment5_grade    48.618522
# assignment6_grade    43.841452
# dtype: float64

# %%
grades.median()
# Out:
# assignment1_grade    77.208365
# assignment2_grade    68.142124
# assignment3_grade    61.307206
# assignment4_grade    54.442888
# assignment5_grade    48.681165
# assignment6_grade    43.172442
# dtype: float64

# %%
grades.mode()
# Out:
#                                 student_id  assignment1_grade  \
# 0     DDE0526B-7DA4-80E8-C2A6-D097F3826029          14.423297
# 1     EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          14.959603
# 2                                      NaN          18.018145
# 3                                      NaN          18.504458
# 4                                      NaN          18.962538
# ...                                    ...                ...
# 2310                                   NaN         100.191182
# 2311                                   NaN         100.214164
# 2312                                   NaN         100.448031
# 2313                                   NaN         100.516064
# 2314                                   NaN         100.695583
#
#              assignment1_submission  assignment2_grade  \
# 0     2015-09-14 23:46:23.696000000          12.980967
# 1     2015-09-15 01:17:24.847000000          14.459603
# ...

# %%
grades.std()
# Out:
# assignment1_grade    16.353252
# assignment2_grade    15.959210
# assignment3_grade    15.492469
# assignment4_grade    14.687431
# assignment5_grade    13.927054
# assignment6_grade    13.259413
# dtype: float64

# %%
grades.dtypes
# Out:
# student_id                 object
# assignment1_grade         float64
# assignment1_submission     object
# assignment2_grade         float64
# assignment2_submission     object
# assignment3_grade         float64
# assignment3_submission     object
# assignment4_grade         float64
# assignment4_submission     object
# assignment5_grade         float64
# assignment5_submission     object
# assignment6_grade         float64
# assignment6_submission     object
# dtype: object

# %%
grades.axes
# Out:
# [RangeIndex(start=0, stop=2315, step=1),
#  Index(['student_id', 'assignment1_grade', 'assignment1_submission',
#         'assignment2_grade', 'assignment2_submission', 'assignment3_grade',
#         'assignment3_submission', 'assignment4_grade', 'assignment4_submission',
#         'assignment5_grade', 'assignment5_submission', 'assignment6_grade',
#         'assignment6_submission'],
#        dtype='object')]

# %%
grades.values
# Out:
# array([['B73F2C11-70F0-E37D-8B10-1D20AFED50B1', 92.73394640624124,
#         '2015-11-02 06:55:34.282000000', ...,
#         '2015-11-20 13:24:59.692000000', 38.16831825359636,
#         '2015-11-22 18:31:15.934000000'],
#        ['98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1', 86.79082085792986,
#         '2015-11-29 14:57:44.429000000', ...,
#         '2015-12-19 23:26:39.285000000', 44.62948153275085,
#         '2015-12-21 17:07:24.275000000'],
#        ['D0F62040-CEB0-904C-F563-2F8620916C4E', 85.51254106831485,
#         '2016-01-09 05:36:02.389000000', ...,
#         '2016-01-11 17:31:12.489000000', 44.32970128981442,
#         '2016-01-17 16:24:42.765000000'],
#        ...,
#        ['EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31', 73.26946265689205,
#         '2015-10-20 08:09:27.418000000', ...,
#         '2015-11-29 14:23:43.659000000', 41.80001049036983,
#         '2015-12-04 09:56:07.156000000'],
#        ['1F51E050-78F7-F270-1B90-ED1BC0376763', 87.26836634630587,
# ...

# %%
grades.head(20)
# Out:
#                               student_id  assignment1_grade  \
# 0   B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1   98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2   D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3   FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4   5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5   D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 6   3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7   F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 8   C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
# 9   E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
# 10  ECFE7BB7-F618-A5B9-7A57-3BD2BCC0D880          45.838780
# 11  B017B4A6-1F41-9D46-A040-21B0D270D4BE          76.670469
# 12  F2A4439C-F8D6-D47D-D884-C62E40366413          92.295151
# 13  8DC055F5-4B63-6CD1-9BAD-A2D927E01CDA          79.129632
# 14  35A9117B-9278-8C97-7180-DC1319117AB8          83.552847
# ...

# %%
grades.tail(20)
# Out:
#                                 student_id  assignment1_grade  \
# 2295  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          38.788636
# 2296  25197F10-E9E9-4C50-63F8-6C896975AAE2          74.106685
# 2297  25197F10-E9E9-4C50-63F8-6C896975AAE2          91.192781
# 2298  DDE0526B-7DA4-80E8-C2A6-D097F3826029          68.571967
# 2299  247B105C-2067-A7AA-2CBE-B65278128C96          58.760286
# 2300  1F51E050-78F7-F270-1B90-ED1BC0376763          88.777948
# 2301  25197F10-E9E9-4C50-63F8-6C896975AAE2          74.260083
# 2302  2B806EF6-A590-1C00-F0C5-1469E3B2152E          62.048275
# 2303  DDE0526B-7DA4-80E8-C2A6-D097F3826029          97.215052
# 2304  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          65.123101
# 2305  5AB0D44C-86FF-2DE6-B096-B0F5D029E430          76.819524
# 2306  DDE0526B-7DA4-80E8-C2A6-D097F3826029          47.696703
# 2307  1F51E050-78F7-F270-1B90-ED1BC0376763          94.595758
# 2308  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          71.481182
# ...

# %%
grades.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
grades.tail()
# Out:
#                                 student_id  assignment1_grade  \
# 2310  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          77.684611
# 2311  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          75.367870
# 2312  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          73.269463
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#              assignment1_submission  assignment2_grade  \
# 2310  2016-03-07 02:52:24.378000000          69.916150
# 2311  2015-11-29 02:43:27.932000000          59.934296
# 2312  2015-10-20 08:09:27.418000000          58.255570
# 2313  2016-04-03 09:04:51.646000000          87.268366
# 2314  2015-10-04 09:46:03.403000000          79.818105
#
#              assignment2_submission  assignment3_grade  \
# 2310  2016-03-11 22:02:39.161000000          69.916150
# 2311  2015-12-03 05:30:39.218000000          48.687437
# 2312  2015-11-18 19:07:06.930000000          58.955570
# ...

# %%
grades.sample(169)
# Out:
#                                 student_id  assignment1_grade  \
# 73    2B806EF6-A590-1C00-F0C5-1469E3B2152E          88.531241
# 1123  1F51E050-78F7-F270-1B90-ED1BC0376763          87.800518
# 2215  2B806EF6-A590-1C00-F0C5-1469E3B2152E          91.610812
# 503   25197F10-E9E9-4C50-63F8-6C896975AAE2          65.008843
# 1408  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          56.276892
# ...                                    ...                ...
# 114   DDE0526B-7DA4-80E8-C2A6-D097F3826029          72.096750
# 2060  DDE0526B-7DA4-80E8-C2A6-D097F3826029          99.018590
# 179   2B806EF6-A590-1C00-F0C5-1469E3B2152E          59.436251
# 2133  2B806EF6-A590-1C00-F0C5-1469E3B2152E          64.670148
# 402   DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          76.127876
#
#              assignment1_submission  assignment2_grade  \
# 73    2015-11-01 19:10:07.890000000          70.464993
# 1123  2015-09-26 13:24:54.500000000          78.590466
# ...

# %%
grades.columns
# Out:
# Index(['student_id', 'assignment1_grade', 'assignment1_submission',
#        'assignment2_grade', 'assignment2_submission', 'assignment3_grade',
#        'assignment3_submission', 'assignment4_grade', 'assignment4_submission',
#        'assignment5_grade', 'assignment5_submission', 'assignment6_grade',
#        'assignment6_submission'],
#       dtype='object')

# %%
grades.min()
# Out:
# student_id                1026AC75-5EB1-292F-A95E-6BBA39BE3FAF
# assignment1_grade                                    14.423297
# assignment1_submission           2015-09-14 23:46:23.696000000
# assignment2_grade                                    12.980967
# assignment2_submission           2015-09-15 00:26:05.259000000
# assignment3_grade                                    12.307682
# assignment3_submission           2015-09-17 01:54:10.003000000
# assignment4_grade                                     9.126146
# assignment4_submission           2015-09-15 02:36:42.216000000
# assignment5_grade                                     8.213531
# assignment5_submission           2015-09-15 02:56:44.957000000
# assignment6_grade                                     7.392178
# assignment6_submission           2015-09-17 18:38:14.285000000
# dtype: object

# %%
grades.mean()
# Out:
# assignment1_grade    74.535732
# assignment2_grade    66.849007
# assignment3_grade    60.623197
# assignment4_grade    54.112112
# assignment5_grade    48.618522
# assignment6_grade    43.841452
# dtype: float64

# %%
grades.median()
# Out:
# assignment1_grade    77.208365
# assignment2_grade    68.142124
# assignment3_grade    61.307206
# assignment4_grade    54.442888
# assignment5_grade    48.681165
# assignment6_grade    43.172442
# dtype: float64

# %%
grades.mode()
# Out:
#                                 student_id  assignment1_grade  \
# 0     DDE0526B-7DA4-80E8-C2A6-D097F3826029          14.423297
# 1     EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          14.959603
# 2                                      NaN          18.018145
# 3                                      NaN          18.504458
# 4                                      NaN          18.962538
# ...                                    ...                ...
# 2310                                   NaN         100.191182
# 2311                                   NaN         100.214164
# 2312                                   NaN         100.448031
# 2313                                   NaN         100.516064
# 2314                                   NaN         100.695583
#
#              assignment1_submission  assignment2_grade  \
# 0     2015-09-14 23:46:23.696000000          12.980967
# 1     2015-09-15 01:17:24.847000000          14.459603
# ...

# %%
grades_assignment1_grade = grades.groupby(['assignment1_grade'])

# %%
grades_assignment1_grade.mean()
# Out:
#                    assignment2_grade  assignment3_grade  assignment4_grade  \
# assignment1_grade
# 14.423297                  12.980967          12.980967          10.384774
# 14.959603                  14.459603          12.307682           9.126146
# 18.018145                  16.216331          14.594698          13.135228
# 18.504458                  18.004458          16.924012          14.421611
# 18.962538                  17.066284          17.066284          15.359656
# ...                              ...                ...                ...
# 100.191182                 99.691182          80.492946          63.674357
# 100.214164                 89.762747          81.506473          80.606473
# 100.448031                 79.998425          64.738740          51.070992
# 100.516064                 80.052851          72.767566          57.494053
# 100.695583                 90.196024          81.896422          80.996422
#
# ...

# %%
grades_sub = grades[grades['assignment1_grade']>80]
grades_sub
# Out:
#                                 student_id  assignment1_grade  \
# 0     B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1     98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2     D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3     FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6     3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# ...                                    ...                ...
# 2303  DDE0526B-7DA4-80E8-C2A6-D097F3826029          97.215052
# 2307  1F51E050-78F7-F270-1B90-ED1BC0376763          94.595758
# 2309  6D2AB78F-44F4-2E8B-5C5E-B79119BC7EAC          82.640274
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#              assignment1_submission  assignment2_grade  \
# 0     2015-11-02 06:55:34.282000000          83.030552
# 1     2015-11-29 14:57:44.429000000          86.290821
# ...

# %%
grades['assignment1_grade']
# Out:
# 0       92.733946
# 1       86.790821
# 2       85.512541
# 3       86.030665
# 4       64.813800
#           ...
# 2310    77.684611
# 2311    75.367870
# 2312    73.269463
# 2313    87.268366
# 2314    80.318105
# Name: assignment1_grade, Length: 2315, dtype: float64

# %%
grades[['assignment1_grade','assignment2_grade']]
# Out:
#       assignment1_grade  assignment2_grade
# 0             92.733946          83.030552
# 1             86.790821          86.290821
# 2             85.512541          85.512541
# 3             86.030665          68.824532
# 4             64.813800          51.491040
# ...                 ...                ...
# 2310          77.684611          69.916150
# 2311          75.367870          59.934296
# 2312          73.269463          58.255570
# 2313          87.268366          87.268366
# 2314          80.318105          79.818105
#
# [2315 rows x 2 columns]

# %%
grades[20:60:6]
# Out:
#                               student_id  assignment1_grade  \
# 20  D5E03B6F-E4AB-AD56-FCB5-12ACA02D3622          82.478383
# 26  D887D9D7-6993-7618-5333-1DBC732CAA5E          81.471342
# 32  25197F10-E9E9-4C50-63F8-6C896975AAE2          82.932464
# 38  1F51E050-78F7-F270-1B90-ED1BC0376763          73.355346
# 44  1F51E050-78F7-F270-1B90-ED1BC0376763          84.397806
# 50  2B806EF6-A590-1C00-F0C5-1469E3B2152E          75.412068
# 56  DDE0526B-7DA4-80E8-C2A6-D097F3826029          83.168765
#
#            assignment1_submission  assignment2_grade  \
# 20  2016-03-03 03:13:32.174000000          65.982706
# 26  2016-01-09 10:52:36.062000000          73.324208
# 32  2016-01-06 00:03:25.671000000          74.639217
# 38  2016-04-30 02:46:23.038000000          66.019811
# 44  2015-12-14 07:48:07.185000000          83.897806
# 50  2015-12-26 17:56:11.158000000          74.912068
# 56  2016-01-11 05:21:36.712000000          66.535012
#
# ...

# %%
grades_sub.loc[15:30,['assignment1_grade','assignment2_grade','assignment3_grade']]
# Out:
#     assignment1_grade  assignment2_grade  assignment3_grade
# 20          82.478383          65.982706          59.384436
# 22          88.901114          70.760891          64.404802
# 23          99.886995          89.898296          89.898296
# 24          88.700055          79.400050          80.100050
# 26          81.471342          73.324208          73.324208
# 28          94.437504          93.937504          94.637504
# 29          90.868490          72.694792          58.155833

# %%
grades_sub.iloc[78:2300,[0,3,6,9]]
# Out:
#                                 student_id  assignment2_grade  \
# 188   2B806EF6-A590-1C00-F0C5-1469E3B2152E          84.089389
# 190   6D2AB78F-44F4-2E8B-5C5E-B79119BC7EAC          75.573372
# 191   247B105C-2067-A7AA-2CBE-B65278128C96          81.225030
# 196   247B105C-2067-A7AA-2CBE-B65278128C96          87.154986
# 197   DDE0526B-7DA4-80E8-C2A6-D097F3826029          77.749123
# ...                                    ...                ...
# 2303  DDE0526B-7DA4-80E8-C2A6-D097F3826029          77.772041
# 2307  1F51E050-78F7-F270-1B90-ED1BC0376763          85.136182
# 2309  6D2AB78F-44F4-2E8B-5C5E-B79119BC7EAC          65.752219
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          79.818105
#
#              assignment3_submission  assignment5_grade
# 188   2016-03-28 16:39:22.246000000          60.544360
# 190   2015-10-19 23:32:47.557000000          54.268828
# ...

# %%
grades.iloc[0]
# Out:
# student_id                B73F2C11-70F0-E37D-8B10-1D20AFED50B1
# assignment1_grade                                    92.733946
# assignment1_submission           2015-11-02 06:55:34.282000000
# assignment2_grade                                    83.030552
# assignment2_submission           2015-11-09 02:22:58.938000000
# assignment3_grade                                    67.164441
# assignment3_submission           2015-11-12 08:58:33.998000000
# assignment4_grade                                    53.011553
# assignment4_submission           2015-11-16 01:21:24.663000000
# assignment5_grade                                    47.710398
# assignment5_submission           2015-11-20 13:24:59.692000000
# assignment6_grade                                    38.168318
# assignment6_submission           2015-11-22 18:31:15.934000000
# Name: 0, dtype: object

# %%
grades.iloc[6]
# Out:
# student_id                3217BE3F-E4B0-C3B6-9F64-462456819CE4
# assignment1_grade                                    87.498744
# assignment1_submission           2016-03-05 11:05:25.408000000
# assignment2_grade                                    69.998995
# assignment2_submission           2016-03-09 07:29:52.405000000
# assignment3_grade                                    55.999196
# assignment3_submission           2016-03-16 22:31:24.316000000
# assignment4_grade                                    50.399276
# assignment4_submission           2016-03-18 07:19:26.032000000
# assignment5_grade                                    45.359349
# assignment5_submission           2016-03-19 10:35:41.869000000
# assignment6_grade                                    45.359349
# assignment6_submission           2016-03-23 14:02:00.987000000
# Name: 6, dtype: object

# %%
grades.iloc[-1]
# Out:
# student_id                DDE0526B-7DA4-80E8-C2A6-D097F3826029
# assignment1_grade                                    80.318105
# assignment1_submission           2015-10-04 09:46:03.403000000
# assignment2_grade                                    79.818105
# assignment2_submission           2015-10-06 10:28:30.820000000
# assignment3_grade                                    64.594484
# assignment3_submission           2015-10-13 17:06:29.179000000
# assignment4_grade                                    50.955587
# assignment4_submission           2015-10-06 16:18:35.513000000
# assignment5_grade                                     40.76447
# assignment5_submission           2015-10-23 17:03:26.939000000
# assignment6_grade                                     40.76447
# assignment6_submission           2015-10-26 15:56:55.460000000
# Name: 2314, dtype: object

# %%
grades.iloc[:,0]
# Out:
# 0       B73F2C11-70F0-E37D-8B10-1D20AFED50B1
# 1       98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1
# 2       D0F62040-CEB0-904C-F563-2F8620916C4E
# 3       FFDF2B2C-F514-EF7F-6538-A6A53518E9DC
# 4       5ECBEEB6-F1CE-80AE-3164-E45E99473FB4
#                         ...
# 2310    DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2
# 2311    DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2
# 2312    EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31
# 2313    1F51E050-78F7-F270-1B90-ED1BC0376763
# 2314    DDE0526B-7DA4-80E8-C2A6-D097F3826029
# Name: student_id, Length: 2315, dtype: object

# %%
grades.iloc[:,-1]
# Out:
# 0       2015-11-22 18:31:15.934000000
# 1       2015-12-21 17:07:24.275000000
# 2       2016-01-17 16:24:42.765000000
# 3       2016-05-26 08:09:12.058000000
# 4       2016-01-05 01:06:59.546000000
#                     ...
# 2310    2016-03-25 11:00:06.923000000
# 2311    2015-12-22 13:34:42.931000000
# 2312    2015-12-04 09:56:07.156000000
# 2313    2016-04-23 03:44:06.813000000
# 2314    2015-10-26 15:56:55.460000000
# Name: assignment6_submission, Length: 2315, dtype: object

# %%
grades.iloc[0:6,0]
# Out:
# 0    B73F2C11-70F0-E37D-8B10-1D20AFED50B1
# 1    98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1
# 2    D0F62040-CEB0-904C-F563-2F8620916C4E
# 3    FFDF2B2C-F514-EF7F-6538-A6A53518E9DC
# 4    5ECBEEB6-F1CE-80AE-3164-E45E99473FB4
# 5    D09000A0-827B-C0FF-3433-BF8FF286E15B
# Name: student_id, dtype: object

# %%
grades.iloc[0:6:3,9]
# Out:
# 0    47.710398
# 3    49.553663
# Name: assignment5_grade, dtype: float64

# %%
grades_sorted = grades.sort_values(by ='assignment3_grade')
grades_sorted
# Out:
#                                 student_id  assignment1_grade  \
# 15    24827B50-2FC2-E4B0-E2A0-1989E17749B3          14.959603
# 1424  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          14.423297
# 2237  247B105C-2067-A7AA-2CBE-B65278128C96          19.524002
# 226   DDE0526B-7DA4-80E8-C2A6-D097F3826029          18.018145
# 1929  2B806EF6-A590-1C00-F0C5-1469E3B2152E          18.504458
# ...                                    ...                ...
# 1174  2B806EF6-A590-1C00-F0C5-1469E3B2152E          97.952182
# 585   EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          99.134693
# 369   DDE0526B-7DA4-80E8-C2A6-D097F3826029          99.581715
# 376   1F51E050-78F7-F270-1B90-ED1BC0376763          99.435672
# 619   2B806EF6-A590-1C00-F0C5-1469E3B2152E          99.455813
#
#              assignment1_submission  assignment2_grade  \
# 15    2015-11-17 01:16:07.800000000          14.459603
# 1424  2016-02-07 21:22:54.096000000          12.980967
# ...

# %%
grades_sorted.head()
# Out:
#                                 student_id  assignment1_grade  \
# 15    24827B50-2FC2-E4B0-E2A0-1989E17749B3          14.959603
# 1424  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          14.423297
# 2237  247B105C-2067-A7AA-2CBE-B65278128C96          19.524002
# 226   DDE0526B-7DA4-80E8-C2A6-D097F3826029          18.018145
# 1929  2B806EF6-A590-1C00-F0C5-1469E3B2152E          18.504458
#
#              assignment1_submission  assignment2_grade  \
# 15    2015-11-17 01:16:07.800000000          14.459603
# 1424  2016-02-07 21:22:54.096000000          12.980967
# 2237  2015-12-26 21:56:19.375000000          15.259202
# 226   2016-01-05 05:43:54.384000000          16.216331
# 1929  2015-09-19 14:32:43.674000000          18.004458
#
#              assignment2_submission  assignment3_grade  \
# 15    2015-11-22 15:00:14.342000000          12.307682
# 1424  2016-02-13 23:00:38.889000000          12.980967
# 2237  2016-01-13 15:58:41.321000000          14.453282
# ...

# %%
grades_sorted.tail()
# Out:
#                                 student_id  assignment1_grade  \
# 1174  2B806EF6-A590-1C00-F0C5-1469E3B2152E          97.952182
# 585   EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          99.134693
# 369   DDE0526B-7DA4-80E8-C2A6-D097F3826029          99.581715
# 376   1F51E050-78F7-F270-1B90-ED1BC0376763          99.435672
# 619   2B806EF6-A590-1C00-F0C5-1469E3B2152E          99.455813
#
#              assignment1_submission  assignment2_grade  \
# 1174  2015-09-20 22:31:11.749000000          97.452182
# 585   2016-05-01 13:33:17.182000000          99.134693
# 369   2016-01-24 07:39:40.106000000          99.581715
# 376   2015-12-06 10:59:42.253000000          98.935672
# 619   2015-11-28 20:42:20.349000000          98.955813
#
#              assignment2_submission  assignment3_grade  \
# 1174  2015-09-27 20:22:42.683000000          98.152182
# 585   2016-05-07 10:46:33.760000000          99.134693
# 369   2016-01-29 07:23:12.099000000          99.581715
# ...

# %%
import numpy as np
n = pd.Series(np.nan, index=[1,2,3,4,5,6])
n
# Out:
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# dtype: float64

# %%
grades.dropna(how='all')
# Out:
#                                 student_id  assignment1_grade  \
# 0     B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1     98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2     D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3     FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4     5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# ...                                    ...                ...
# 2310  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          77.684611
# 2311  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          75.367870
# 2312  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          73.269463
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#              assignment1_submission  assignment2_grade  \
# 0     2015-11-02 06:55:34.282000000          83.030552
# 1     2015-11-29 14:57:44.429000000          86.290821
# ...

# %%
grades.dropna(axis=1,how='all')
# Out:
#                                 student_id  assignment1_grade  \
# 0     B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1     98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2     D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3     FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4     5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# ...                                    ...                ...
# 2310  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          77.684611
# 2311  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          75.367870
# 2312  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          73.269463
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#              assignment1_submission  assignment2_grade  \
# 0     2015-11-02 06:55:34.282000000          83.030552
# 1     2015-11-29 14:57:44.429000000          86.290821
# ...

# %%
grades.notnull()
# Out:
#       student_id  assignment1_grade  assignment1_submission  \
# 0           True               True                    True
# 1           True               True                    True
# 2           True               True                    True
# 3           True               True                    True
# 4           True               True                    True
# ...          ...                ...                     ...
# 2310        True               True                    True
# 2311        True               True                    True
# 2312        True               True                    True
# 2313        True               True                    True
# 2314        True               True                    True
#
#       assignment2_grade  assignment2_submission  assignment3_grade  \
# 0                  True                    True               True
# 1                  True                    True               True
# ...

# %%
grades[['assignment1_grade','assignment2_grade']].agg(['min','mean','max'])
# Out:
#       assignment1_grade  assignment2_grade
# min           14.423297          12.980967
# mean          74.535732          66.849007
# max          100.695583          99.936206

# %%
grades.var()
# Out:
# assignment1_grade    267.428841
# assignment2_grade    254.696381
# assignment3_grade    240.016589
# assignment4_grade    215.720625
# assignment5_grade    193.962827
# assignment6_grade    175.812026
# dtype: float64

# %%
grades.std()
# Out:
# assignment1_grade    16.353252
# assignment2_grade    15.959210
# assignment3_grade    15.492469
# assignment4_grade    14.687431
# assignment5_grade    13.927054
# assignment6_grade    13.259413
# dtype: float64

# %%
grades.sem()
# Out:
# assignment1_grade    0.339882
# assignment2_grade    0.331693
# assignment3_grade    0.321992
# assignment4_grade    0.305260
# assignment5_grade    0.289457
# assignment6_grade    0.275581
# dtype: float64

# %%
grades.skew()
# Out:
# assignment1_grade   -0.638347
# assignment2_grade   -0.342592
# assignment3_grade   -0.164887
# assignment4_grade   -0.034779
# assignment5_grade    0.094916
# assignment6_grade    0.276608
# dtype: float64

# %%
grades.kurt()
# Out:
# assignment1_grade   -0.061094
# assignment2_grade   -0.211822
# assignment3_grade   -0.214601
# assignment4_grade   -0.219539
# assignment5_grade   -0.081467
# assignment6_grade    0.086712
# dtype: float64

# %%
j = pd.Series({0:45,1:456,2:897,3:986})
j
# Out:
# 0     45
# 1    456
# 2    897
# 3    986
# dtype: int64

# %%
j.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
j.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# dtype: bool

# %%
ipl_trophies = pd.Series({'MI': 5,
                             'CSK': 3,
                             'KKR': 2,
                             'Dc': 1})
t20_worldcup_hosts = pd.Series(['Australia',
                                      'India',
                                      'West Indies',
                                      'Afghanisthan'], 
                                   index=['Hosts',
                                          'Hosts',
                                          'Hosts',
                                          'Host'])
t20 = ipl_trophies.append(t20_worldcup_hosts)

# %%
ipl_trophies
# Out:
# MI     5
# CSK    3
# KKR    2
# Dc     1
# dtype: int64

# %%
t20_worldcup_hosts
# Out:
# Hosts       Australia
# Hosts           India
# Hosts     West Indies
# Host     Afghanisthan
# dtype: object

# %%
t20
# Out:
# MI                  5
# CSK                 3
# KKR                 2
# Dc                  1
# Hosts       Australia
# Hosts           India
# Hosts     West Indies
# Host     Afghanisthan
# dtype: object

# %%
t20.index[0]
# Out:
# 'MI'

# %%
type(t20.index[0])
# Out:
# str

# %%
type(t20.index)
# Out:
# pandas.core.indexes.base.Index

# %%
type(ipl_trophies.index)
# Out:
# pandas.core.indexes.base.Index

# %%
t20.iloc[5]
# Out:
# 'India'

# %%
t20.loc['Hosts']
# Out:
# Hosts      Australia
# Hosts          India
# Hosts    West Indies
# dtype: object

# %%
import pandas as pd
cricketer_1 = pd.Series({'Name': 'Chris Gayle',
                        'Centuries': 34,
                        'Half-Centuries': 82})
cricketer_2 =pd.Series({'Name': 'Rohit Sharma',
                        'Centuries': 42,
                        'Half-Centuries': 72})
cricketer_3 = pd.Series({'Name': 'Virat Kohli',
                        'Centuries': 38,
                        'Half-Centuries': 66})
review = pd.DataFrame([cricketer_1,cricketer_2,cricketer_3], index=['player_1','player_2','player_3'])
review.head()
# Out:
#                   Name  Centuries  Half-Centuries
# player_1   Chris Gayle         34              82
# player_2  Rohit Sharma         42              72
# player_3   Virat Kohli         38              66

# %%
review.loc['player_2']
# Out:
# Name              Rohit Sharma
# Centuries                   42
# Half-Centuries              72
# Name: player_2, dtype: object

# %%
review.iloc[1]
# Out:
# Name              Rohit Sharma
# Centuries                   42
# Half-Centuries              72
# Name: player_2, dtype: object

# %%
type(review)
# Out:
# pandas.core.frame.DataFrame

# %%
type(review.loc['player_2'])
# Out:
# pandas.core.series.Series

# %%
review.T
# Out:
#                    player_1      player_2     player_3
# Name            Chris Gayle  Rohit Sharma  Virat Kohli
# Centuries                34            42           38
# Half-Centuries           82            72           66
